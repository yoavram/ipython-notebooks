# %% [markdown]
# # Fixation of a beneficial allele

# %%
from scipy import __version__ as ver
print "Scipy", ver
from numpy import __version__ as ver
print "Numpy", ver
from matplotlib import __version__ as ver
print "Matplotlib", ver
from IPython import __version__ as ver
print "IPython", ver
from pandas import __version__ as ver
print "pandas", ver
from datetime import datetime
import os
import dill

rcParams['figure.figsize'] = (8,6)
rcParams['font.size'] = 14
rcParams['lines.linewidth'] = 2
 
#simulations_filename = "/home/yoavram/workspace/ipython-notebooks/fixation_simulations.csv"
pool = None
# Out:
# Scipy 0.14.0
# Numpy 1.8.1
# Matplotlib 1.3.1
# IPython 2.0.0
# pandas 0.13.1
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-ebd0bc48beb6> in <module>()
#      11 from datetime import datetime
#      12 import os
# ---> 13 import dill
#      14
#      15 rcParams['figure.figsize'] = (8,6)
#
# ImportError: No module named dill

# %%
from IPython.display import display, HTML 
dt = datetime.now()
display(HTML("<h2>" + dt.ctime() + "</h2>"))
# Out:
# <h2>Sun Jun  1 12:34:10 2014</h2>

# %% [markdown]
# ### Wright-Fisher Simulation

# %%
def simulate_fixation(s, N, x, PLOT=False):
    N = int(N)
    if PLOT:
        _ = []
    t = 0
    while not (allclose(x,1) or allclose(x,0)):
        assert 0 < x < 1
        t += 1
        if PLOT: _.append(x)
        x = x/(1-s+s*x)
        n = binomial(N,x)
        x = n/float(N)
        if PLOT: 
            if len(_)%100 == 0:
                print len(_),
    if PLOT:
        plot(range(len(_)), _)
        ylim(-0.1,1)
        xlim(0,max(10,len(_)))
        xlabel("Time")
        ylabel("Frequency")
    return allclose(x,1), t

while not simulate_fixation(0.1, 1e3, 1e-3, True)[0]:
    pass
# Out:
# 100

# %%
def p_simulation(s, N, x, replicates=100):
    '''if os.path.exists(simulations_filename):
        print "File found.",
        df = pd.read_csv(simulations_filename)
    else:
        df = pd.DataFrame(columns=['type','s','N','x','fixation_success','fixation_time'])
    df_slice = df[(df['type']=='simple_wf') & (df['s']==s) & (df['N']==N) & (df['x']==x)]
    print "%d results found." % len(df_slice),
    if len(df_slice) < replicates:
        print "Running %d more simulations." % (replicates - len(df_slice)),'''
    if pool:       
        results = pool.map_async(simulate_fixation, range(replicates), s=s, N=N, x=1./N, plot=False)
    else:
        results = [simulate_fixation(s, N, x, False) for _ in range(replicates)]# - len(df))]
    d = [{'s':s,'N':N,'x':x,'type':'simple_wf','fixation_success':fixation_success,'fixation_time':fixation_time} for (fixation_success,fixation_time) in results]       
    d = pd.DataFrame(d)
    #if len(df):
    #    print "Concatinating.",
    #    df = pd.concat((df, d), ignore_index=True)
    #else:
    df = d
    #print "Writing new results to %s." % simulations_filename
    #df.to_csv(simulations_filename, index=False)
    df_slice = df#[(df['type']=='simple_wf') & (df['s']==s) & (df['N']==N) & (df['x']==x)]
    return df_slice['fixation_success'].mean(), df_slice['fixation_success'].std(ddof=1)/sqrt(len(df_slice))
p_simulation(0.1, 1e5, 1e-5, 101)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d33e785a4984> in <module>()
#      24     df_slice = df#[(df['type']=='simple_wf') & (df['s']==s) & (df['N']==N) & (df['x']==x)]
#      25     return df_slice['fixation_success'].mean(), df_slice['fixation_success'].std(ddof=1)/sqrt(len(df_slice))
# ---> 26 p_simulation(0.1, 1e5, 1e-5, 101)
#
# <ipython-input-10-d33e785a4984> in p_simulation(s, N, x, replicates)
#      10         print "Running %d more simulations." % (replicates - len(df_slice)),'''
#      11     if pool:
# ---> 12         results = pool.map_async(simulate_fixation, range(replicates), s=s, N=N, x=1./N, plot=False)
#      13     else:
#      14         results = [simulate_fixation(s, N, x, False) for _ in range(replicates)]# - len(df))]
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in map_async(self, f, *sequences, **kwargs)
#     352             raise TypeError("map_async doesn't take a `block` keyword argument.")
#     353         kwargs['block'] = False
# --> 354         return self.map(f,*sequences,**kwargs)
#     355
#     356     def map_sync(self, f, *sequences, **kwargs):
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in map(self, f, *sequences, **kwargs)
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in sync_results(f, self, *args, **kwargs)
#      64     self._in_sync_results = True
#      65     try:
# ---> 66         ret = f(self, *args, **kwargs)
#      67     finally:
#      68         self._in_sync_results = False
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in map(self, f, *sequences, **kwargs)
#     618         for k in kwargs.keys():
#     619             if k not in ['block', 'track']:
# --> 620                 raise TypeError("invalid keyword arg, %r"%k)
#     621
#     622         assert len(sequences) > 0, "must have some sequences to map onto!"
#
# TypeError: invalid keyword arg, 'x'

# %% [markdown]
# ### Large population

# %%
def p_eshel(s,N,x):
    return (2*s)**N

# %% [markdown]
# ### Small population

# %%
def p_kimura(s,N,x):
    return (1-exp(-2*N*s*x))/(1-exp(-2*N*s))

# %% [markdown]
# ### Comparison

# %%
def plot_kimura_eshel_simulation(x, kimura=None, eshel=None, simulation=None, xlabel='', ylabel='p'):
    fig,ax = subplots(1,1)
    if kimura != None: ax.plot(x, kimura, label='Diffusion')
    if eshel != None: ax.plot(x, eshel, label='1st Order')
    if simulation != None: ax.plot(x, simulation, 'og', alpha=0.5, label='Simulation')
    ax.legend(loc=9)
    ax.set_xscale('log')
    ax.grid(False,'minor')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xlim(min(x)/2,max(x)*2)
    low,high = ax.get_ylim()
    ax.set_ylim(low-(high-low)/10, high+(high-low)/10)
    return fig,ax

# %%
from IPython.parallel import Client
pool = Client()[:]
print "# CPUs",len(pool.client.ids)
with pool.sync_imports():
    from numpy import allclose, mean
    from numpy.random import binomial
pool['simulate_fixation'] = simulate_fixation
pool['p_simulation'] = p_simulation
# Out:
# # CPUs 10
# importing allclose,mean from numpy on engine(s)
# importing binomial from numpy.random on engine(s)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-05c42ba573ac> in <module>()
#       6     from numpy.random import binomial
#       7 pool['simulate_fixation'] = simulate_fixation
# ----> 8 pool['p_simulation'] = p_simulation
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in __setitem__(self, key, value)
#     805
#     806     def __setitem__(self,key, value):
# --> 807         self.update({key:value})
#     808
#     809     def clear(self, targets=None, block=None):
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in update(self, ns)
#     688         See `push` for details.
#     689         """
# --> 690         return self.push(ns, block=self.block, track=self.track)
#     691
#     692     def push(self, ns, targets=None, block=None, track=None):
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in push(self, ns, targets, block, track)
#     709         if not isinstance(ns, dict):
#     710             raise TypeError("Must be a dict, not %s"%type(ns))
# --> 711         return self._really_apply(util._push, kwargs=ns, block=block, track=track, targets=targets)
#     712
#     713     def get(self, key_s):
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in _really_apply(self, f, args, kwargs, targets, block, track)
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in sync_results(f, self, *args, **kwargs)
#      64     self._in_sync_results = True
#      65     try:
# ---> 66         ret = f(self, *args, **kwargs)
#      67     finally:
#      68         self._in_sync_results = False
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in _really_apply(self, f, args, kwargs, targets, block, track)
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in save_ids(f, self, *args, **kwargs)
#      49     n_previous = len(self.client.history)
#      50     try:
# ---> 51         ret = f(self, *args, **kwargs)
#      52     finally:
#      53         nmsgs = len(self.client.history) - n_previous
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/view.pyc in _really_apply(self, f, args, kwargs, targets, block, track)
#     565         for ident in _idents:
#     566             msg = self.client.send_apply_request(self._socket, f, args, kwargs, track=track,
# --> 567                                     ident=ident)
#     568             if track:
#     569                 trackers.append(msg['tracker'])
#
# /usr/local/lib/python2.7/dist-packages/IPython/parallel/client/client.pyc in send_apply_request(self, socket, f, args, kwargs, metadata, track, ident)
#    1252         bufs = serialize.pack_apply_message(f, args, kwargs,
#    1253             buffer_threshold=self.session.buffer_threshold,
# -> 1254             item_threshold=self.session.item_threshold,
#    1255         )
#    1256
#
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/serialize.pyc in pack_apply_message(f, args, kwargs, buffer_threshold, item_threshold)
#     159
#     160     kw_keys = sorted(kwargs.keys())
# --> 161     kwarg_bufs = flatten(serialize_object(kwargs[key], buffer_threshold, item_threshold) for key in kw_keys)
#     162
#     163     info = dict(nargs=len(args), narg_bufs=len(arg_bufs), kw_keys=kw_keys)
#
# /usr/local/lib/python2.7/dist-packages/IPython/utils/data.pyc in flatten(seq)
#      28     """Flatten a list of lists (NOT recursive, only works for 2d lists)."""
#      29
# ---> 30     return [x for subseq in seq for x in subseq]
#      31
#      32
#
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/serialize.pyc in <genexpr>((key,))
#     159
#     160     kw_keys = sorted(kwargs.keys())
# --> 161     kwarg_bufs = flatten(serialize_object(kwargs[key], buffer_threshold, item_threshold) for key in kw_keys)
#     162
#     163     info = dict(nargs=len(args), narg_bufs=len(arg_bufs), kw_keys=kw_keys)
#
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/serialize.pyc in serialize_object(obj, buffer_threshold, item_threshold)
#     100         buffers.extend(_extract_buffers(cobj, buffer_threshold))
#     101
# --> 102     buffers.insert(0, pickle.dumps(cobj,-1))
#     103     return buffers
#     104
#
# /usr/local/lib/python2.7/dist-packages/IPython/utils/codeutil.pyc in reduce_code(co)
#      36 def reduce_code(co):
#      37     if co.co_freevars or co.co_cellvars:
# ---> 38         raise ValueError("Sorry, cannot pickle code objects with closures")
#      39     args =  [co.co_argcount, co.co_nlocals, co.co_stacksize,
#      40             co.co_flags, co.co_code, co.co_consts, co.co_names,
#
# ValueError: Sorry, cannot pickle code objects with closures

# %%
N_range = array(map(int,logspace(3,7,5)))
s = 0.01
print N_range
# Out:
# [    1000    10000   100000  1000000 10000000]

# %%
p_simulation_N = [p_simulation(s, N, 1./N, replicates=100) for N in N_range]

# %%
p_eshel_N  = p_eshel(s, N_range, 1./N_range) 
p_kimura_N = p_kimura(s, N_range, 1./N_range)

# %%
p_simulation_N
# Out:
# [(0.02, 0.014070529413628963),
#  (0.029999999999999999, 0.017144660799776522),
#  (0.01, 0.0099999999999999967),
#  (0.02, 0.014070529413628957),
#  (0.029999999999999999, 0.017144660799776529)]

# %%
plot_kimura_eshel_simulation(N_range, p_kimura_N, p_eshel_N, p_simulation_N, 'N');

# %%
N = int(1e6)
s_range = logspace(-4,-1,50)

# %%
p_simulation_s = load_or_run("p_simulation_s_N_1e%d.gz" % log10(N), 
                             lambda: pool.map_sync(lambda s,N: p_simulation(s, N, 1./N, 1000), s_range, [N]*len(s_range)),
                             force_calc=False)
# Out:
# Calculating...
# Saving results to p_simulation_s_N_1e6.gz

# %%
p_eshel_s  = p_eshel(s_range, N, 1./N)
p_kimura_s = p_kimura(s_range, N, 1./N)

# %%
plot_kimura_eshel_simulation(s_range, p_kimura_s, p_eshel_s, p_simulation_s, 's');

# %% [markdown]
# ## Fixation time
#
# ### Diffusion model
#
# The following formula is taken from eq. (17) in [Kimura and Ohta 1969](http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=1212239) which assumes a population size of _2N_ gametes and selection advantage of _s/2_ rather then _N_ and _s_, therefore I'm changing $s=2s$ and $N=N/2$.

# %%
from scipy.integrate import quad as integral

# %%
def integrand1(s, N, x):
    if x == 1:
        return 0
    return (1 - exp(-2*N*s*x) - exp(-2*N*s*(1-x)) + exp(-2*N*s)) / (x*(1-x))

def integrand2(s,N,x):
    if x == 0:
        return 0
    return (exp(2*N*s*x) - 1) * (1 - exp(-2*N*s*x))/(x*(1-x))

def T_kimura(s,N,x):
    J1 = 1/(s*(1 - exp(-2*N*s))) * integral(lambda t: integrand1(s,N,t), x, 1)[0]
    u = (1-exp(-2*N*s*x))/(1-exp(-2*N*s))
    J2 = 1/(s*(1-exp(-2*N*s))) * integral(lambda t: integrand2(s,N,t), 0, x)[0]
    return J1 + ((1-u)/u) * J2
T_kimura(0.1, 1e6, 1e-6)
# Out:
# 254.66622091258296

# %% [markdown]
# ### Determinisic model
#
# A different approach, attributed to [Haldane 1924](http://link.springer.com/article/10.1007%2FBF02459574) (via [Hartfiled & Otto 2011](http://www.ncbi.nlm.nih.gov/pubmed/21884046)) is derived like this:
# the time-series of the frequency of the beneficial allele can be approximated by:
# $$
# f(t) = \frac{f(0)}{f(0) + (1-f(0))(1-s)^t}.
# $$
# Inversing this equation allows us to find the fixation time $T_{fix}$:
# $$
# (1-s)^{T_{fix}} = \frac{(1-f(T_{fix}))f(T_0)}{f(T_{fix})(1-f(T_0))} \Rightarrow \\\\
# T_{fix} = \frac{\log{ \frac{(1-f(T_{fix}))f(T_0)}{f(T_{fix})(1-f(T_0))} }}{\log{1-s}}.
# $$
# Taking $f(0)=1/N, f(T_{fix})=\frac{N-1}{N}, \log{N-1} \approx \log{N}, \log{1-s} \approx -s$ we get:
# $$
# T_{fix} = 2 \frac{\log{N}}{s}
# $$

# %% [markdown]
# ## Simulation

# %%
def T_simulation(s,N,x,replicates=100):
    Ts = [simulate_fixation(s, N, 1./N) for _ in range(replicates)]
    return mean([t[1] for t in Ts if t[0]])
pool['T_simulation'] = T_simulation
T_simulation(0.1, 1e5, 1e-5)
# Out:
# 198.69565217391303

# %% [markdown]
# ### Comparison

# %%
N_range = map(int,logspace(3,8,50))
s = 0.01

# %%
T_kimura_N    = [T_kimura(s, N, 1./N) for N in N_range]
T_haldane_N   = [-2*log(N)/log(1-s) for N in N_range]

# %%
T_simulation_N = pool.map_sync(lambda s,N: T_simulation(s, N, 1./N, 1000), [s]*len(N_range), N_range)

# %%
plot_kimura_eshel_simulation(N_range, T_kimura_N, T_haldane_N, T_simulation_N, xlabel='N', ylabel='T');

# %%
N = int(1e6)
s_range = logspace(-3,-1,50)

# %%
T_kimura_s    = [T_kimura(s, N, 1./N) for s in s_range]
T_haldane_s   = [2*log(N)/log(1+s) for s in s_range]

# %%
T_simulation_s = pool.map_sync(lambda s,N: T_simulation(s, N, 1./N, 1000), s_range, [N]*len(s_range))

# %%
plot_kimura_eshel_simulation(s_range, T_kimura_s, T_haldane_s, T_simulation_s, xlabel='s', ylabel='T');
