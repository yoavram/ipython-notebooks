# %%
from PIL import Image

# %%
cd d:\university\python course\11
# Out:
# d:\university\python course\11

# %%
def show(image):
    matplotlib.pyplot.imshow(numpy.asarray(image),matplotlib.cm.gray);

# %%
im = Image.open("lena.bmp")

# %%
show(im)

# %%
ls
# Out:
#  Volume in drive D is Purple24
#  Volume Serial Number is 12B2-607F
#
#  Directory of d:\university\python course\11
#
# 12/30/2012  01:44 PM    <DIR>          .
# 12/30/2012  01:44 PM    <DIR>          ..
# 01/08/2012  01:06 PM            10,952 buildings.jpg
# 12/23/2012  04:02 PM    <DIR>          ex
# 01/07/2012  11:02 PM           420,918 face.bmp
# 01/06/2012  12:30 AM            66,614 lena.bmp
# 12/30/2012  01:43 PM             1,346 moedAQ2.py
# 01/10/2012  09:22 PM             2,249 morphological.py
# 01/10/2012  09:22 PM             1,714 otsu.py
# 12/23/2012  11:36 AM           530,356 PyProg1112a_moedA.pdf
# 01/07/2012  10:31 PM            42,694 salt_paper_lena.bmp
# 12/23/2012  11:24 AM         2,102,123 ta10_2011.pptx
# 12/30/2012  01:43 PM         2,050,856 ta11.pptx
# 12/23/2012  11:24 AM           431,474 ta11_code.zip
# 12/30/2012  01:42 PM            66,718 tmp.bmp
#               12 File(s)      5,728,014 bytes
# ...

# %%
import moedAQ2

# %%
dir(moedAQ2)
# Out:
# ['Image',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'build_hist',
#  'cum_sum',
#  'find_thrds',
#  'h',
#  'im',
#  'out',
#  'pixels_mat',
#  'trinary_sementation',
#  'w']

# %%
im2 = moedAQ2.trinary_sementation(im.load(), im.size[0], im.size[1])

# %%
show(im2)

# %%
import PIL

# %%
PIL.Image.VERSION
# Out:
# '1.1.7'
