# %%
import csv, gzip
import pandas as pd

# %%
print pd.version.version
# Out:
# 0.12.0

# %%
with gzip.open(r"D:\workspace\ruggedsim\stochastic\output\df_unloaded.csv.gz") as f:
    df = pd.read_csv(f)

# %%
df = df[df['U'] == 0.0004]
df = df[df['pi'] == 10.00]
df = df[df['pop_size'] == 1000000]
df = df[df['s'] == 0.05]
df = df[df['beta'] == 0.0002]
print len(df)
# Out:
# 16310

# %%
import seaborn as sns # version 0.2.dev

# %%
sns.regplot("tau", "app_time", df)
