# %%
import sympy
print sympy.__version__
sympy.init_printing(use_unicode=False, wrap_line=False, no_global=True, use_latex=True)
# Out:
# 0.7.4.1

# %%
z, xi, x, x0, n, s = sympy.symbols("z xi x x0 n s", real=True)

# %%
def G(xi):
    return sympy.exp( 2 * n * 0.6 * s * xi * (xi - x0) / x0 )

# %%
T = sympy.integrate( 2 * n /(x * G(x)) * sympy.integrate(G(z), (z, 0, x)),  (x, 0,  x0))
# Out:
# ---------------------------------------------------------------------------
# DomainError                               Traceback (most recent call last)
# <ipython-input-15-cdb83dc585c2> in <module>()
# ----> 1 T = sympy.integrate( 2 * n /(x * G(x)) * sympy.integrate(G(z), (z, 0, x)),  (x, 0,  x0))
#
# c:\python27\lib\site-packages\sympy\utilities\decorator.pyc in threaded_func(expr, *args, **kwargs)
#      33                                       func(expr.rhs, *args, **kwargs))
#      34             else:
# ---> 35                 return func(expr, *args, **kwargs)
#      36
#      37     return threaded_func
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in integrate(*args, **kwargs)
#    1281     if isinstance(integral, Integral):
#    1282         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1283                              risch=risch, manual=manual)
#    1284     else:
#    1285         return integral
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in doit(self, **hints)
#     553                     function, xab[0],
#     554                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 555                     conds=conds)
#     556                 if antideriv is None and meijerg1 is True:
#     557                     ret = try_meijerg(function, xab)
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     949                             result = result.func(*[
#     950                                 arg.doit(manual=False) if arg.has(Integral) else arg
# --> 951                                 for arg in result.args
#     952                             ]).expand(multinomial=False,
#     953                                       log=False,
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in doit(self, **hints)
#     470         function = self.function
#     471         if deep:
# --> 472             function = function.doit(**hints)
#     473
#     474         if function.is_zero:
#
# c:\python27\lib\site-packages\sympy\core\basic.pyc in doit(self, **hints)
#    1571         if hints.get('deep', True):
#    1572             terms = [ term.doit(**hints) if isinstance(term, Basic) else term
# -> 1573                                          for term in self.args ]
#    1574             return self.func(*terms)
#    1575         else:
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in doit(self, **hints)
#     553                     function, xab[0],
#     554                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 555                     conds=conds)
#     556                 if antideriv is None and meijerg1 is True:
#     557                     ret = try_meijerg(function, xab)
#
# c:\python27\lib\site-packages\sympy\integrals\integrals.pyc in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     809         if risch is not False:
#     810             try:
# --> 811                 result, i = risch_integrate(f, x, separate_integral=True, conds=conds)
#     812             except NotImplementedError:
#     813                 pass
#
# c:\python27\lib\site-packages\sympy\integrals\risch.pyc in risch_integrate(f, x, extension, handle_first, separate_integral, rewrite_complex, conds)
#    1674         fa, fd = fa.cancel(fd, include=True)
#    1675         if case == 'exp':
# -> 1676             ans, i, b = integrate_hyperexponential(fa, fd, DE, conds=conds)
#    1677         elif case == 'primitive':
#    1678             ans, i, b = integrate_primitive(fa, fd, DE)
#
# c:\python27\lib\site-packages\sympy\integrals\risch.pyc in integrate_hyperexponential(a, d, DE, z, conds)
#    1421     pp = as_poly_1t(p, DE.t, z)
#    1422
# -> 1423     qa, qd, b = integrate_hyperexponential_polynomial(pp, DE, z)
#    1424
#    1425     i = pp.nth(0, 0)
#
# c:\python27\lib\site-packages\sympy\integrals\risch.pyc in integrate_hyperexponential_polynomial(p, DE, z)
#    1376             iDta, iDtd = frac_in(iDt, DE.t, field=True)
#    1377             try:
# -> 1378                 va, vd = rischDE(iDta, iDtd, Poly(aa, DE.t), Poly(ad, DE.t), DE)
#    1379                 va, vd = frac_in((va, vd), t1)
#    1380             except NonElementaryIntegralException:
#
# c:\python27\lib\site-packages\sympy\integrals\rde.pyc in rischDE(fa, fd, ga, gd, DE)
#     721     implemented.
#     722     """
# --> 723     _, (fa, fd) = weak_normalizer(fa, fd, DE)
#     724     a, (ba, bd), (ca, cd), hn = normal_denom(fa, fd, ga, gd, DE)
#     725     A, B, C, hs = special_denom(a, ba, bd, ca, cd, DE)
#
# c:\python27\lib\site-packages\sympy\integrals\rde.pyc in weak_normalizer(a, d, DE, z)
#      96     """
#      97     z = z or Dummy('z')
# ---> 98     dn, ds = splitfactor(d, DE)
#      99
#     100     # Compute d1, where dn == d1*d2**2*...*dn**n is a square-free
#
# c:\python27\lib\site-packages\sympy\integrals\risch.pyc in splitfactor(p, DE, coefficientD, z)
#     867
#     868     One = Poly(1, DE.t, domain=p.get_domain())
# --> 869     Dp = derivation(p, DE, coefficientD=coefficientD)
#     870     # XXX: Is this right?
#     871     if p.is_zero:
#
# c:\python27\lib\site-packages\sympy\integrals\risch.pyc in derivation(p, DE, coefficientD, basic)
#     822             r += d.as_expr()*pv.diff(v)
#     823         else:
# --> 824             r += (d*pv.diff(v)).as_poly(t)
#     825
#     826     if basic:
#
# c:\python27\lib\site-packages\sympy\core\decorators.pyc in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# c:\python27\lib\site-packages\sympy\polys\polytools.pyc in __mul__(f, g)
#    3692                 return f.as_expr()*g
#    3693
# -> 3694         return f.mul(g)
#    3695
#    3696     @_sympifyit('g', NotImplemented)
#
# c:\python27\lib\site-packages\sympy\polys\polytools.pyc in mul(f, g)
#    1347             return f.mul_ground(g)
#    1348
# -> 1349         _, per, F, G = f._unify(g)
#    1350
#    1351         if hasattr(f.rep, 'mul'):
#
# c:\python27\lib\site-packages\sympy\polys\polytools.pyc in _unify(f, g)
#     355             gens = _unify_gens(f.gens, g.gens)
#     356
# --> 357             dom, lev = f.rep.dom.unify(g.rep.dom, gens), len(gens) - 1
#     358
#     359             if f.gens != gens:
#
# c:\python27\lib\site-packages\sympy\polys\domains\domain.pyc in unify(K0, K1, symbols)
#     248         """
#     249         if symbols is not None:
# --> 250             return K0.unify_with_symbols(K1, symbols)
#     251
#     252         if K0 == K1:
#
# c:\python27\lib\site-packages\sympy\polys\domains\domain.pyc in unify_with_symbols(K0, K1, symbols)
#     228             raise UnificationFailed("can't unify %s with %s, given %s generators" % (K0, K1, tuple(symbols)))
#     229
# --> 230         return K0.unify(K1)
#     231
#     232     def unify(K0, K1, symbols=None):
#
# c:\python27\lib\site-packages\sympy\polys\domains\domain.pyc in unify(K0, K1, symbols)
#     272                  K1.is_FractionField and K0.is_PolynomialRing) and
#     273                  (not K0_ground.has_Field or not K1_ground.has_Field) and domain.has_Field):
# --> 274                 domain = domain.get_ring()
#     275
#     276             if K0.is_Composite and (not K1.is_Composite or K0.is_FractionField or K1.is_PolynomialRing):
#
# c:\python27\lib\site-packages\sympy\polys\domains\realfield.pyc in get_ring(self)
#     104     def get_ring(self):
#     105         """Returns a ring associated with ``self``. """
# --> 106         raise DomainError('there is no ring associated with %s' % self)
#     107
#     108     def get_exact(self):
#
# DomainError: there is no ring associated with RR

# %%
T.subs({x0:0.5}).evalf()
