# %%
cd D:\workspace\masim\Johnston
# Out:
# D:\workspace\masim\Johnston

# %%
fin = open("Yeast.MA.ColonyGrowth.YPD.csv")
fout = open("Yeast.MA.ColonyGrowth.YPD.proccessed.csv", "w")
for line in fin:
    fields = [x.replace("-",",") for x in line.split(",")]
    if fields[0] != "" and not fields[-1].stratswith("#DIV/0!"):
        print fields[-1]
        fout.write(",".join(fields))
fin.close()
fout.close()
# Out:
# r
#
# #DIV/0!
#
# 0.873889374
#
# 0.855924548
#
# 0.834815457
#
# 0.818634166
#
# 0.877194011
#
# 0.776072447
#
# 0.799618532
#
# 0.779251625
#
# 0.890109003
#
# 0.901113782
#
# 0.789676135
#
# 0.788126618
#
# 0.816033328
#
# 0.929531376
#
# 0.825991631
#
# 0.765178378
#
# 0.793362535
#
# 0.908450488
#
# 0.855738314
#
# 0.759462778
#
# 0.778661187
#
# 0.788706969
#
# 0.781376993
#
# 0.755219604
#
# 0.876884428
#
# 0.783971467
#
# 0.846829386
#
# 0.788373147
#
# 0.913077902
#
# 0.782750173
#
# 0.779639993
#
# 0.731301628
#
# 0.790046366
#
# 0.852194687
#
# 0.80848403
#
# 0.832574618
#
# 0.784430746
#
# 0.807953012
#
# 0.770339305
#
# 0.853181142
#
# 0.884300941
#
# 0.754240125
#
# 0.886865054
#
# 0.868639596
#
# 0.868567415
#
# 0.807440141
#
# 0.827389574
#
# 0.88013627
#
# 0.749843307
#
# 0.853201158
#
# 0.85664444
#
# 0.773894225
#
# 0.755865404
#
# 0.785928955
#
# 0.861995153
#
# 0.848023822
#
# 0.748431103
#
# 0.759792754
#
# 0.748153231
#
# 0.710849749
#
# 0.754493872
#
# ...
